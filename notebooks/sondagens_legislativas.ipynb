# %%
import pandas as pd

# %%
# _OBN - soma os votos em "Outros" (partidos ou opções não listados), "Brancos" e "Nulos"

# _N - Norte
# _C - Centro
# _SI - Sul e Ilhas
# _AML - Area Metropolitana de Lisboa
# _AMP - Area Metropolitana do Porto

# _Alen - Area Metropolitana do Porto
# _Alg - Area Metropolitana do Porto

# _M - Masculino
# _F - Feminino

# _1834 - dos 18 aos 34 anos
# _3554 - dos 35 aos 54 anos
# _55 - dos 55 anos para cima

# _3549 - dos 35 aos 49 anos
# _5064 - dos 50 aos 64 anos
# _65 - dos 65 anos para cima

# _AB - pessoas da classe A e B
# _C1 - pessoas da classe C1
# _C2D - pessoas da classe C2 e D

'''
Classe A - Elite ou classe alta, altos executivos, grandes empresários, profissionais liberais de alto rendimento (médicos, advogados, etc.), ou pessoas com património significativo.
Classe B - Classe média-alta, profissionais qualificados (ex.: professores universitários, engenheiros, gestores intermédios), com rendimentos confortáveis e bom nível de educação (geralmente com formação superior).
Classe C1 - Classe média "típica", trabalhadores de "colarinho branco" (white-collar workers) em funções administrativas, técnicas ou de supervisão (ex.: funcionários públicos, técnicos de nível intermédio, pequenos empresários, empregados de escritório).
Classe C2 - Classe trabalhadora, trabalhadores manuais qualificados (blue-collar workers), como operários especializados, carpinteiros, eletricistas, ou outros profissionais que dependem de trabalho físico.
Classe D - Classe baixa, incluindo trabalhadores não qualificados (ex.: empregados de limpeza, trabalhadores agrícolas), desempregados, ou pessoas com rendimentos muito baixos, como pensionistas com pensões mínimas.
'''

features = ["Entidade_de_sondagens", "Cliente", "Data_de_Recolha", "Data_de_publicação", "Ultimo_dia_de_recolha",
"Tamanho_da_amostra", "Taxa_de_resposta", 
"Num_M", "Num_F", "Taxa_M", "Taxa_F", 
"Num_1834", "Num_1824", "Num_2544", "Num_4564", "Num_3554", "Num_55", "Num_3549", "Num_5064", "Num_65", "Taxa_1834", "Taxa_1824", "Taxa_2544", "Taxa_4564", "Taxa_3554", "Taxa_55", "Taxa_3549", "Taxa_5064", "Taxa_65",
"Num_N", "Num_C", "Num_SI", "Num_AML", "Num_AMP", "Num_Alen", "Num_Alg", "Taxa_N", "Taxa_C", "Taxa_SI", "Taxa_AML", "Taxa_AMP", "Taxa_Alen", "Taxa_Alg",
"Num_AB", "Num_C1", "Num_C2", "Num_D", "Num_C2D", "Taxa_AB", "Taxa_C1", "Taxa_C2D", "Taxa_C2", "Taxa_D",
"Intervalo_de_confiança", "Margem_de_erro","Votos_em_branco", "Votos_nulo", 
"OBN_ind", "Abstencao_ind","PS_ind", "AD_ind", "PSD_ind", "Chega_ind", "IL_ind", "BE_ind", "CDU_ind", "Livre_ind", "PAN_ind", "CDS_ind",
"Indecisos","OBN", "Abstencao","PS", "AD", "PSD", "Chega", "IL", "BE", "CDU", "Livre", "PAN", "CDS",
"Indecisos_M","OBN_M", "Abstencao_M","PS_M", "AD_M", "PSD_M", "Chega_M", "IL_M", "BE_M", "CDU_M", "Livre_M", "PAN_M", "CDS_M",
"Indecisos_F","OBN_F", "Abstencao_F","PS_F", "AD_F", "PSD_F", "Chega_F", "IL_F", "BE_F", "CDU_F", "Livre_F", "PAN_F", "CDS_F",
"Indecisos_N","OBN_N", "Abstencao_N","PS_N", "AD_N", "PSD_N", "Chega_N", "IL_N", "BE_N", "CDU_N", "Livre_N", "PAN_N", "CDS_N",
"Indecisos_C","OBN_C", "Abstencao_C","PS_C", "AD_C", "PSD_C", "Chega_C", "IL_C", "BE_C", "CDU_C", "Livre_C", "PAN_C", "CDS_C",
"Indecisos_AML","OBN_AML", "Abstencao_AML","PS_AML", "AD_AML", "PSD_AML", "Chega_AML", "IL_AML", "BE_AML", "CDU_AML", "Livre_AML", "PAN_AML", "CDS_AML",
"Indecisos_SI","OBN_SI", "Abstencao_SI","PS_SI", "AD_SI", "PSD_SI", "Chega_SI", "IL_SI", "BE_SI", "CDU_SI", "Livre_SI", "PAN_SI", "CDS_SI", 
"Indecisos_1834","OBN_1834", "Abstencao_1834","PS_1834", "AD_1834", "PSD_1834", "Chega_1834", "IL_1834", "BE_1834", "CDU_1834", "Livre_1834", "PAN_1834", "CDS_1834", 
"Indecisos_3554","OBN_3554", "Abstencao_3554","PS_3554", "AD_3554", "PSD_3554", "Chega_3554", "IL_3554", "BE_3554", "CDU_3554", "Livre_3554", "PAN_3554", "CDS_3554", 
"Indecisos_55","OBN_55", "Abstencao_55","PS_55", "AD_55", "PSD_55", "Chega_55", "IL_55", "BE_55", "CDU_55", "Livre_55", "PAN_55", "CDS_55", 
"Indecisos_3549","OBN_3549", "Abstencao_3549","PS_3549", "AD_3549", "PSD_3549", "Chega_3549", "IL_3549", "BE_3549", "CDU_3549", "Livre_3549", "PAN_3549", "CDS_3549",
"Indecisos_5064","OBN_5064", "Abstencao_5064","PS_5064", "AD_5064", "PSD_5064", "Chega_5064", "IL_5064", "BE_5064", "CDU_5064", "Livre_5064", "PAN_5064", "CDS_5064", 
"Indecisos_65","OBN_65", "Abstencao_65","PS_65", "AD_65", "PSD_65", "Chega_65", "IL_65", "BE_65", "CDU_65", "Livre_65", "PAN_65", "CDS_65",  
"Indecisos_AB","OBN_AB", "Abstencao_AB","PS_AB", "AD_AB", "PSD_AB", "Chega_AB", "IL_AB", "BE_AB", "CDU_AB", "Livre_AB", "PAN_AB", "CDS_AB", 
"Indecisos_C1","OBN_C1", "Abstencao_C1","PS_C1", "AD_C1", "PSD_C1", "Chega_C1", "IL_C1", "BE_C1", "CDU_C1", "Livre_C1", "PAN_C1", "CDS_C1",
"Indecisos_C2","OBN_C2", "Abstencao_C2","PS_C2", "AD_C2", "PSD_C2", "Chega_C2", "IL_C2", "BE_C2", "CDU_C2", "Livre_C2", "PAN_C2", "CDS_C2",  
"Indecisos_C2D","OBN_C2D", "Abstencao_C2D","PS_C2D", "AD_C2D", "PSD_C2D", "Chega_C2D", "IL_C2D", "BE_C2D", "CDU_C2D", "Livre_C2D", "PAN_C2D", "CDS_C2D", 
"Indecisos_D","OBN_D", "Abstencao_D","PS_D", "AD_D", "PSD_D", "Chega_D", "IL_D", "BE_D", "CDU_D", "Livre_D", "PAN_D", "CDS_D", 
"Observacao"]

# %%
sondagem_legislativas_pitagorica_07012025 = {
"Entidade_de_sondagens": "Pitagórica", "Cliente": "TVI, CNN Portugal, JN, TSF, O Jogo", 
"Data_de_Recolha": "28/12/2024-05/01/2025", "Data_de_publicação": "07/01/2025", "Ultimo_dia_de_recolha": "05/01/2025",
"Tamanho_da_amostra": 400, "Taxa_de_resposta": 65.36, 
"Num_M": 185, "Num_F": 215, "Taxa_M": 46.25, "Taxa_F": 53.75, 
"Num_1834": 98, "Num_3554": 129, "Num_55": 173, "Taxa_1834": 24.5, "Taxa_3554": 32.25, "Taxa_55": 43.25,
"Num_N": 140, "Num_C": 86, "Num_SI": 61, "Num_AML": 113, "Num_AMP": None, "Taxa_N": None, "Taxa_C": None, "Taxa_SI": None, "Taxa_AML": None, "Taxa_AMP": None,
"Num_AB": 158, "Num_C1": 136, "Num_C2D": 106, "Taxa_AB": 39.5, "Taxa_C1": 34.0, "Taxa_C2D": 26.5,
"Intervalo_de_confiança": 95.5, "Margem_de_erro": 5, "Votos_em_branco": None, "Votos_nulo": None, 
# Intenção de voto geral
"Indecisos": 12.5, "OBN": 4.7, "Abstencao": None, "PS": 23.5, "AD": 28.7, "PSD": None, "Chega": 14.2, "IL": 5.0, "BE": 3.8, "CDU": 3.5, "Livre": 2.8, "PAN": 1.3, "CDS": None,
# Intenção de voto por sexo
"Indecisos_M": 14.1, "OBN_M": 2.7, "Abstencao_M": None, "PS_M": 22.7, "AD_M": 27.6, "PSD_M": None, "Chega_M": 15.1, "IL_M": 5.9, "BE_M": 3.8, "CDU_M": 4.3, "Livre_M": 2.7, "PAN_M": 1.1, "CDS_M": None,
"Indecisos_F": 11.2, "OBN_F": 6.5, "Abstencao_F": None, "PS_F": 24.2, "AD_F": 29.8, "PSD_F": None, "Chega_F": 13.5, "IL_F": 4.2, "BE_F": 3.7, "CDU_F": 2.8, "Livre_F": 2.8, "PAN_F": 1.4, "CDS_F": None,
"Indecisos_N": 12.9, "OBN_N": 6.4, "Abstencao_N": None, "PS_N": 22.1, "AD_N": 30.7, "PSD_N": None, "Chega_N": 14.3, "IL_N": 3.6, "BE_N": 4.3, "CDU_N": 2.9, "Livre_N": 1.4, "PAN_N": 1.4, "CDS_N": None,
"Indecisos_C": 14.0, "OBN_C": 3.5, "Abstencao_C": None, "PS_C": 24.4, "AD_C": 30.2, "PSD_C": None, "Chega_C": 14.0, "IL_C": 5.8, "BE_C": 1.2, "CDU_C": 5.8, "Livre_C": 1.2, "PAN_C": 0.0, "CDS_C": None,
"Indecisos_AML": 12.4, "OBN_AML": 4.4, "Abstencao_AML": None, "PS_AML": 21.2, "AD_AML": 26.5, "PSD_AML": None, "Chega_AML": 14.2, "IL_AML": 5.3, "BE_AML": 5.3, "CDU_AML": 2.7, "Livre_AML": 5.3, "PAN_AML": 2.7, "CDS_AML": None,
"Indecisos_SI": 9.8, "OBN_SI": 3.3, "Abstencao_SI": None, "PS_SI": 27.5, "AD_SI": 26.2, "PSD_SI": None, "Chega_SI": 14.8, "IL_SI": 6.6, "BE_SI": 3.3, "CDU_SI": 3.3, "Livre_SI": 3.3, "PAN_SI": 0.0, "CDS_SI": None,
# Intenção de voto por faixa etária
"Indecisos_1834": 15.3, "OBN_1834": 5.1, "Abstencao_1834": None, "PS_1834": 12.2, "AD_1834": 23.5, "PSD_1834": None, "Chega_1834": 20.4, "IL_1834": 13.3, "BE_1834": 3.1, "CDU_1834": 1.0, "Livre_1834": 3.1, "PAN_1834": 3.1, "CDS_1834": None,
"Indecisos_3554": 14.0, "OBN_3554": 3.9, "Abstencao_3554": None, "PS_3554": 19.4, "AD_3554": 28.7, "PSD_3554": None, "Chega_3554": 17.1, "IL_3554": 5.4, "BE_3554": 3.9, "CDU_3554": 3.9, "Livre_3554": 2.3, "PAN_3554": 1.6, "CDS_3554": None,
"Indecisos_55": 9.8, "OBN_55": 5.2, "Abstencao_55": None, "PS_55": 32.9, "AD_55": 31.8, "PSD_55": None, "Chega_55": 8.7, "IL_55": 0.0, "BE_55": 4.0, "CDU_55": 4.6, "Livre_55": 2.7, "PAN_55": 0.0, "CDS_55": None,
# Intenção de voto por status social
"Indecisos_AB": 6.3, "OBN_AB": 3.8, "Abstencao_AB": None, "PS_AB": 24.7, "AD_AB": 34.8, "PSD_AB": None, "Chega_AB": 8.2, "IL_AB": 8.2, "BE_AB": 3.2, "CDU_AB": 3.8, "Livre_AB": 5.7, "PAN_AB": 1.3, "CDS_AB": None,
"Indecisos_C1": 16.9, "OBN_C1": 5.9, "Abstencao_C1": None, "PS_C1": 21.3, "AD_C1": 27.9, "PSD_C1": None, "Chega_C1": 16.2, "IL_C1": 2.9, "BE_C1": 3.7, "CDU_C1": 2.9, "Livre_C1": 1.5, "PAN_C1": 0.7, "CDS_C1": None,
"Indecisos_C2D": 16.0, "OBN_C2D": 4.7, "Abstencao_C2D": None, "PS_C2D": 24.5, "AD_C2D": 20.8, "PSD_C2D": None, "Chega_C2D": 20.8, "IL_C2D": 2.8, "BE_C2D": 4.7, "CDU_C2D": 3.8, "Livre_C2D": 0.0, "PAN_C2D": 1.9, "CDS_C2D": None,
"Observacao": "VOTO DIRETO S/DIST. DE INDECISOS; AD e PS estão separados por 6pp e em empate técnico (C/Dist. Indecisos); Distância AD-PS: Total=5.2%, Masculino=4.9%, Feminino=5.6%, 18-34=11.2%, 35-54=9.3%, 55+=-1.2%, Norte=8.6%, Centro=5.8%, Lisboa=5.3%; Distribuição da Amostra por Região: Norte=35.0%, Centro=21.5%, Lisboa (assumido como AML)=28.25%, Sul+Ilhas=15.25%; Fidelidade de Voto (Março 2024-Janeiro 2025): AD=82.9%, PS=76.7%, CDU=92.3%, BE=73.7%, PAN=71.4%, Livre=55.6%, Chega=78.8%, IL=76.0%, O+B/N=69.2%; Transferência de Voto (exemplo): 2.4% dos eleitores AD migram para PS, 1.6% para Chega; 1.7% dos eleitores PS migram para Chega."
}


sondagem_legislativas_Aximage_24012025 = {
# Informações gerais
"Entidade_de_sondagens": "Aximage", "Cliente": "Jornal Folha Nacional",
"Data_de_Recolha": "16/01/2025-21/01/2025", "Data_de_publicação": "24/01/2025", "Ultimo_dia_de_recolha": "21/01/2025",
"Tamanho_da_amostra": 802, "Taxa_de_resposta": 35.54, "Intervalo_de_confiança": 95.0, "Margem_de_erro": 3.5,
# Sexo
"Num_M": 383, "Num_F": 419, "Taxa_M": 47.75, "Taxa_F": 52.24,
# Faixa etária
"Num_1834": 189, "Num_3549": 231, "Num_5064": 212, "Num_65": 170,
"Taxa_1834": 23.56, "Taxa_3549": 28.80, "Taxa_5064": 26.43, "Taxa_65": 21.20,
# Regiões
"Num_N": 133, "Num_AMP": 136, "Num_C": 175, "Num_AML": 247, "Num_SI": 111,
"Taxa_N": 16.58, "Taxa_AMP": 16.96, "Taxa_C": 21.82, "Taxa_AML": 30.80, "Taxa_SI": 13.84,
# Status social
"Num_D": 99, "Num_C2": 212, "Num_C1": 253, "Num_AB": 238,
"Taxa_D": 12.34, "Taxa_C2": 26.43, "Taxa_C1": 31.55, "Taxa_AB": 29.68, "Taxa_C2D": 38.78,
# Intenção de voto geral
"Indecisos": 7.5, "OBN": 3.5,
"PS": 24.7, "AD": 26.9, "Chega": 19.0, "IL": 5.8, "BE": 4.1, "CDU": 3.0, "Livre": 3.2, "PAN": 2.3,
# Intenção de voto por sexo
"Indecisos_M": 4.7, "OBN_M": 3.3, "PS_M": 22.2, "AD_M": 26.3, "Chega_M": 21.7, "IL_M": 9.1, "BE_M": 2.7, "CDU_M": 5.0, "Livre_M": 2.7, "PAN_M": 2.3,
"Indecisos_F": 10.1, "OBN_F": 3.9, "PS_F": 27.1, "AD_F": 27.6, "Chega_F": 16.3, "IL_F": 2.5, "BE_F": 5.5, "CDU_F": 1.1, "Livre_F": 3.7, "PAN_F": 2.3,
# Intenção de voto por região
"Indecisos_N": 10.6, "OBN_N": 1.9, "PS_N": 21.4, "AD_N": 31.7, "Chega_N": 16.2, "IL_N": 7.2, "BE_N": 5.1, "CDU_N": 1.4, "Livre_N": 1.8, "PAN_N": 1.9,
"Indecisos_AMP": 6.2, "OBN_AMP": 6.8, "PS_AMP": 26.0, "AD_AMP": 25.3, "Chega_AMP": 20.1, "IL_AMP": 5.7, "BE_AMP": 6.7, "CDU_AMP": 3.0, "Livre_AMP": 0.0, "PAN_AMP": 0.0,
"Indecisos_C": 6.8, "OBN_C": 2.0, "PS_C": 26.0, "AD_C": 37.5, "Chega_C": 15.5, "IL_C": 5.3, "BE_C": 5.8, "CDU_C": 0.0, "Livre_C": 0.0, "PAN_C": 1.3,
"Indecisos_AML": 8.5, "OBN_AML": 2.3, "PS_AML": 24.5, "AD_AML": 20.3, "Chega_AML": 22.8, "IL_AML": 6.8, "BE_AML": 2.0, "CDU_AML": 4.2, "Livre_AML": 5.8, "PAN_AML": 2.3,
"Indecisos_SI": 12.6, "OBN_SI": 0.8, "PS_SI": 30.1, "AD_SI": 22.1, "Chega_SI": 17.3, "IL_SI": 2.8, "BE_SI": 2.0, "CDU_SI": 5.8, "Livre_SI": 5.0, "PAN_SI": 1.4,
# Intenção de voto por faixa etária
"Indecisos_1834": 6.3, "OBN_1834": 5.2, "PS_1834": 21.9, "AD_1834": 28.3, "Chega_1834": 19.0, "IL_1834": 5.6, "BE_1834": 6.1, "CDU_1834": 0.0, "Livre_1834": 3.7, "PAN_1834": 3.8,
"Indecisos_3549": 11.0, "OBN_3549": 5.5, "PS_3549": 19.7, "AD_3549": 26.0, "Chega_3549": 19.9, "IL_3549": 5.0, "BE_3549": 3.1, "CDU_3549": 4.6, "Livre_3549": 2.3, "PAN_3549": 2.9,
"Indecisos_5064": 5.7, "OBN_5064": 1.7, "PS_5064": 25.5, "AD_5064": 28.1, "Chega_5064": 22.3, "IL_5064": 6.7, "BE_5064": 4.2, "CDU_5064": 0.9, "Livre_5064": 3.2, "PAN_5064": 2.3,
"Indecisos_65": 6.6, "OBN_65": 2.7, "PS_65": 25.1, "AD_65": 25.3, "Chega_65": 13.8, "IL_65": 5.8, "BE_65": 3.0, "CDU_65": 6.9, "Livre_65": 4.0, "PAN_65": 1.6,
# Intenção de voto por status social
"Indecisos_D": 7.5, "OBN_D": 1.3, "PS_D": 20.3, "AD_D": 17.5, "Chega_D": 34.4, "IL_D": 4.0, "BE_D": 2.5, "CDU_D": 5.0, "Livre_D": 1.3, "PAN_D": 6.2,
"Indecisos_C2": 3.9, "OBN_C2": 4.5, "PS_C2": 22.0, "AD_C2": 28.8, "Chega_C2": 22.1, "IL_C2": 6.1, "BE_C2": 3.9, "CDU_C2": 3.5, "Livre_C2": 1.8, "PAN_C2": 3.4,
"Indecisos_C1": 9.0, "OBN_C1": 4.0, "PS_C1": 28.3, "AD_C1": 24.3, "Chega_C1": 17.3, "IL_C1": 4.7, "BE_C1": 2.5, "CDU_C1": 4.4, "Livre_C1": 3.4, "PAN_C1": 2.0,
"Indecisos_AB": 8.8, "OBN_AB": 3.2, "PS_AB": 31.9, "AD_AB": 23.9, "Chega_AB": 12.9, "IL_AB": 7.2, "BE_AB": 6.4, "CDU_AB": 0.5, "Livre_AB": 5.0, "PAN_AB": 0.4,
# Observação
"Observacao": "Sondagem realizada com 673 entrevistas CAWI e 129 CATI. Amostragem por quotas cruzando sexo, idade e região (NUTSII). Margem de erro por segmento: Norte=8.5%, Centro=7.4%, AML=6.2%, Sul e Ilhas=9.3%, Masculino=5.0%, Feminino=4.8%, 18-34=7.1%. Resultados brutos estão no anexo Intenção_voto_e_atualidade_política_Janeiro2025.pdf, não redistribuídos."
}

sondagem_legislativas_Intercampus_27012025 = {
# Informações gerais
"Entidade_de_sondagens": "Intercampus", "Cliente": "CM, CMTV, Jornal Negócios",
"Data_de_Recolha": "21/01/2025-26/01/2025", "Data_de_publicação": "27/01/2025", "Ultimo_dia_de_recolha": "27/01/2025",
"Tamanho_da_amostra": 638, "Taxa_de_resposta": 60.2, "Intervalo_de_confiança": 95, "Margem_de_erro": 3.9,
# Sexo
"Num_M": 311, "Num_F": 327, "Taxa_M": 48.74, "Taxa_F": 51.25,
# Faixa etária
"Num_1834": 131, "Num_3554": 224, "Num_55": 283, "Taxa_1834": 20.5, "Taxa_3554": 35.1, "Taxa_55": 44.4,
# Regiões (ajustado para corresponder às tuas chaves)
"Num_N": 240, "Num_C": 147, "Num_AML": 175, "Num_Alg": 29, "Num_Alen": 47,  # AMP não especificado, assumi None
"Taxa_N": 37.6, "Taxa_C": 23.0, "Taxa_AML": 27.4, "Taxa_Alg": 4.5, "Taxa_Alen": 7.4,
# Intenção de voto geral (valores sem abstencionistas, mas incompletos no PDF)
"Votos_em_branco": None, "Votos_nulo": None, 
"Indecisos": 12.3, "OBN": 2.7, "Abstencao": None, "PS": 24.7, "AD": 24.4, "PSD": None, "Chega": 15.2, "IL": 6.1, "BE": 5.2, "CDU": 3.0, "Livre": 3.4, "PAN": 3.0, "CDS": None,
 # Observação
"Observacao": "Resultados dizem respeito a intenções de voto sem abstencionistas. Dados detalhados por sexo, região, faixa etária e status social não foram fornecidos no documento."
}


sondagem_legislativas_ICS_ISCTE_29012025 = {
# Informações gerais
"Entidade_de_sondagens": "ICS/ISCTE", "Cliente": "Grupo Impresa",
"Data_de_Recolha": "09/01/2025-26/01/2025", "Data_de_publicação": "20/01/2025", "Ultimo_dia_de_recolha": "26/01/2025",
"Tamanho_da_amostra": 805, "Taxa_de_resposta": 26.49, "Intervalo_de_confiança": 95, "Margem_de_erro": 3.45,
# Sexo
"Num_M": 378, "Num_F": 427, "Taxa_M": 46.95, "Taxa_F": 53.04,
# Faixa etária
"Num_1834": 59, "Num_3554": 224, "Num_55": 283, "Taxa_1834": 20.5, "Taxa_3554": 35.1, "Taxa_55": 44.4,
# Regiões (ajustado para corresponder às tuas chaves)
"Num_N": 240, "Num_C": 147, "Num_AML": 175, "Num_Alg": 29, "Num_Alen": 47,  # AMP não especificado, assumi None
"Taxa_N": 37.6, "Taxa_C": 23.0, "Taxa_AML": 27.4, "Taxa_Alg": 4.5, "Taxa_Alen": 7.4,
# Intenção de voto geral (valores sem abstencionistas, mas incompletos no PDF)
"Votos_em_branco": 2.1, "Votos_nulo": 0.2, 
"Indecisos": 15.9, "OBN": 1, "Abstencao": 6, "PS": 23.9, "AD": 24, "PSD": None, "Chega": 14.2, "IL": 3.7, "BE": 2.4, "CDU": 2.5, "Livre": 1.6, "PAN": 1.4, "CDS": None,
 # Observação
"Observacao": "Resultados dizem respeito a intenções de voto sem abstencionistas. Dados detalhados por sexo, região, faixa etária e status social não foram fornecidos no documento."
}



sondagem_legislativas_pitagorica_31012025 = {
"Entidade_de_sondagens": "Pitagórica", "Cliente": "TVI, CNN Portugal, JN, TSF, O Jogo", 
"Data_de_Recolha": "21/01/2025-26/01/2025", "Data_de_publicação": "31/01/202", "Ultimo_dia_de_recolha": "26/01/2025",
"Tamanho_da_amostra": 400, "Taxa_de_resposta": 65.36, 
"Num_M": 185, "Num_F": 215, "Taxa_M": 46.25, "Taxa_F": 53.75, 
"Num_1834": 98, "Num_3554": 129, "Num_55": 173, "Taxa_1834": 24.5, "Taxa_3554": 32.25, "Taxa_55": 43.25,
"Num_N": 137, "Num_C": 90, "Num_SI": 62, "Num_AML": 111, "Taxa_N": 34.25, "Taxa_C": 22.5, "Taxa_SI": 15.5, "Taxa_AML": 27.75,
"Num_AB": 178, "Num_C1": 123, "Num_C2D": 99, "Taxa_AB": 44.5, "Taxa_C1": 30.75, "Taxa_C2D": 24.75,
"Intervalo_de_confiança": 95.5, "Margem_de_erro": 5, "Votos_em_branco": None, "Votos_nulo": None, 
# Intenção de voto geral
"Indecisos": 12.0, "OBN": 3.8, "Abstencao": None, "PS": 24.0, "AD": 29.0, "PSD": None, "Chega": 14.8, "IL": 5.5, "BE": 2.8, "CDU": 3.0, "Livre": 3.3, "PAN": 1.8, "CDS": None,
# Intenção de voto por sexo
"Indecisos_M": 10.3, "OBN_M": 4.3, "Abstencao_M": None, "PS_M": 23.2, "AD_M": 28.1, "PSD_M": None, "Chega_M": 18.9, "IL_M": 7.0, "BE_M": 2.2, "CDU_M": 2.7, "Livre_M": 2.7, "PAN_M": 0.5, "CDS_M": None,
"Indecisos_F": 13.5, "OBN_F": 3.7, "Abstencao_F": None, "PS_F": 24.7, "AD_F": 29.8, "PSD_F": None, "Chega_F": 11.2, "IL_F": 4.2, "BE_F": 3.3, "CDU_F": 3.3, "Livre_F": 3.7, "PAN_F": 2.8, "CDS_F": None,
# Regiões
"Indecisos_N": 10.2, "OBN_N": 5.1, "Abstencao_N": None, "PS_N": 21.9, "AD_N": 35.0, "PSD_N": None, "Chega_N": 9.5, "IL_N": 5.8, "BE_N": 5.1, "CDU_N": 0.7, "Livre_N": 2.9, "PAN_N": 3.6, "CDS_N": None,
"Indecisos_C": 11.1, "OBN_C": 3.3, "Abstencao_C": None, "PS_C": 24.4, "AD_C": 28.9, "PSD_C": None, "Chega_C": 15.6, "IL_C": 6.7, "BE_C": 1.1, "CDU_C": 4.4, "Livre_C": 3.3, "PAN_C": 1.1, "CDS_C": None,
"Indecisos_AML": 13.5, "OBN_AML": 0.9, "Abstencao_AML": None, "PS_AML": 27.9, "AD_AML": 21.6, "PSD_AML": None, "Chega_AML": 17.1, "IL_AML": 6.3, "BE_AML": 2.7, "CDU_AML": 5.4, "Livre_AML": 3.6, "PAN_AML": 0.9, "CDS_AML": None,
"Indecisos_SI": 14.5, "OBN_SI": 8.1, "Abstencao_SI": None, "PS_SI": 21.0, "AD_SI": 29.0, "PSD_SI": None, "Chega_SI": 21.0, "IL_SI": 1.6, "BE_SI": None, "CDU_SI": 1.6, "Livre_SI": 3.2, "PAN_SI": None, "CDS_SI": None,
# Intenção de voto por faixa etária
"Indecisos_1834": 12.2, "OBN_1834": 3.1, "Abstencao_1834": None, "PS_1834": 14.3, "AD_1834": 20.4, "PSD_1834": None, "Chega_1834": 20.4, "IL_1834": 12.2, "BE_1834": 4.1, "CDU_1834": 5.1, "Livre_1834": 6.1, "PAN_1834": 2.0, "CDS_1834": None,
"Indecisos_3554": 11.6, "OBN_3554": 4.7, "Abstencao_3554": None, "PS_3554": 20.9, "AD_3554": 31.8, "PSD_3554": None, "Chega_3554": 17.1, "IL_3554": 4.7, "BE_3554": 3.1, "CDU_3554": 0, "Livre_3554": 3.9, "PAN_3554": 2.3, "CDS_3554": None,
"Indecisos_55": 12.1, "OBN_55": 4.0, "Abstencao_55": None, "PS_55": 31.8, "AD_55": 31.8, "PSD_55": None, "Chega_55": 9.8, "IL_55": 2.3, "BE_55": 1.7, "CDU_55": 4, "Livre_55": 1.2, "PAN_55": 1.2, "CDS_55": None,
# Intenção de voto por status social
"Indecisos_AB": 11.2, "OBN_AB": 3.9, "Abstencao_AB": None, "PS_AB": 23.6, "AD_AB": 33.1, "PSD_AB": None, "Chega_AB": 8.4, "IL_AB": 7.9, "BE_AB": 1.7, "CDU_AB": 3.4, "Livre_AB": 3.9, "PAN_AB": 2.8, "CDS_AB": None,
"Indecisos_C1": 11.4, "OBN_C1": 3.3, "Abstencao_C1": None, "PS_C1": 23.6, "AD_C1": 20.3, "PSD_C1": None, "Chega_C1": 21.1, "IL_C1": 6.5, "BE_C1": 4.9, "CDU_C1": 3.3, "Livre_C1": 4.1, "PAN_C1": 0.8, "CDS_C1": None,
"Indecisos_C2D": 14.1, "OBN_C2D": 5.1, "Abstencao_C2D": None, "PS_C2D": 25.3, "AD_C2D": 32.3, "PSD_C2D": None, "Chega_C2D": 18.2, "IL_C2D": 0, "BE_C2D": 2.0, "CDU_C2D": 2.0, "Livre_C2D": 0, "PAN_C2D": 1.0, "CDS_C2D": None,
"Observacao": "VOTO DIRETO S/DIST. DE INDECISOS; AD e PS estão separados por 5pp e em empate técnico; Distância AD-PS: Total=5.0%, Masculino=4.9%, Feminino=5.1%, 18-34=6.1%, 35-54=10.9%, 55+=0.0%, Norte=13.1%, Centro=4.5%, Lisboa=-6.3%, Sul+Ilhas=8.0%; Distribuição da Amostra por Região: Norte=34.25%, Centro=22.5%, Lisboa (assumido como AML)=27.75%, Sul+Ilhas=15.5%; Dados detalhados de fidelidade de voto e transferência de voto não fornecidos na imagem."
}




sondagem_legislativas_Aximage_01022025 = {
# Informações gerais
"Entidade_de_sondagens": "Aximage", "Cliente": "Diário de Notícias",
"Data_de_Recolha": "23/01/2025-28/01/2025", "Data_de_publicação": "01/02/2025", "Ultimo_dia_de_recolha": "28/01/2025",
"Tamanho_da_amostra": 800, "Taxa_de_resposta": 68.36, "Intervalo_de_confiança": 95.0, "Margem_de_erro": 3.5,
# Sexo
"Num_M": 380, "Num_F": 420, "Taxa_M": 47.75, "Taxa_F": 52.24,
# Faixa etária
"Num_1834": 170, "Num_3549": 210, "Num_5064": 199, "Num_65": 221,
"Taxa_1834": 21.25, "Taxa_3549": 26.25, "Taxa_5064": 24.875, "Taxa_65": 27.625,
# Regiões
"Num_N": 128, "Num_AMP": 140, "Num_C": 164, "Num_AML": 243, "Num_SI": 125,
"Taxa_N": 16.0, "Taxa_AMP": 17.5, "Taxa_C": 20.5, "Taxa_AML": 30.375, "Taxa_SI": 15.625,
# Status social
"Num_D": 108, "Num_C2": 228, "Num_C1": 275, "Num_AB": 189,
"Taxa_D": 13.5, "Taxa_C2": 28.5, "Taxa_C1": 34.375, "Taxa_AB": 23.625, "Taxa_C2D": 42.0,
# Intenção de voto geral
"Indecisos": 7.8, "OBN": 4.2, "PS": 25.7, "AD": 26.1, "Chega": 16.5, "IL": 5.5, "BE": 3.7, "CDU": 3.5, "Livre": 4.1, "PAN": 2.9,
# Intenção de voto por sexo
"Indecisos_M": None, "OBN_M": 3.6, "PS_M": 27.1, "AD_M": 30.5, "Chega_M": 22.8, "IL_M": 5.5, "BE_M": 3.5, "CDU_M": 3.5, "Livre_M": 2.9, "PAN_M": 0.7,
"Indecisos_F": None, "OBN_F": 4.9, "PS_F": 28.9, "AD_F": 28.3, "Chega_F": 14.4, "IL_F": 5.8, "BE_F": 4.0, "CDU_F": 3.6, "Livre_F": 5.3, "PAN_F": 4.9,
# Intenção de voto por região
"Indecisos_N": None, "OBN_N": 2.0, "PS_N": 29.7, "AD_N": 28.4, "Chega_N": 20.7, "IL_N": 10.7, "BE_N": 0.9, "CDU_N": 1.9, "Livre_N": 2.9, "PAN_N": 2.9,
"Indecisos_AMP": None, "OBN_AMP": 5.3, "PS_AMP": 24.4, "AD_AMP": 33.9, "Chega_AMP": 15.3, "IL_AMP": 6.2, "BE_AMP": 3.5, "CDU_AMP": 3.5, "Livre_AMP": 5.4, "PAN_AMP": 2.7,
"Indecisos_C": None, "OBN_C": 3.5, "PS_C": 26.8, "AD_C": 33.5, "Chega_C": 17.2, "IL_C": 6.1, "BE_C": 6.1, "CDU_C": 2.7, "Livre_C": 1.7, "PAN_C": 2.7,
"Indecisos_AML": None, "OBN_AML": 3.6, "PS_AML": 30.7, "AD_AML": 25.7, "Chega_AML": 18.7, "IL_AML": 3.1, "BE_AML": 3.6, "CDU_AML": 4.6, "Livre_AML": 7.2, "PAN_AML": 2.6,
"Indecisos_SI": None, "OBN_SI": 7.7, "PS_SI": 27.0, "AD_SI": 26.8, "Chega_SI": 20.0, "IL_SI": 2.9, "BE_SI": 4.9, "CDU_SI": 4.7, "Livre_SI": 2.0, "PAN_SI": 3.9,
# Intenção de voto por faixa etária
"Indecisos_1834": None, "OBN_1834": 5.6, "PS_1834": 18.5, "AD_1834": 26.7, "Chega_1834": 25.9, "IL_1834": 11.5, "BE_1834": 3.8, "CDU_1834": 1.6, "Livre_1834": 6.4, "PAN_1834": 0.0,
"Indecisos_3549": None, "OBN_3549": 5.2, "PS_3549": 25.4, "AD_3549": 26.3, "Chega_3549": 20.7, "IL_3549": 5.4, "BE_3549": 2.4, "CDU_3549": 3.1, "Livre_3549": 5.8, "PAN_3549": 5.7,
"Indecisos_5064": None, "OBN_5064": 2.4, "PS_5064": 26.4, "AD_5064": 35.1, "Chega_5064": 17.9, "IL_5064": 4.7, "BE_5064": 5.7, "CDU_5064": 1.9, "Livre_5064": 1.3, "PAN_5064": 4.5,
"Indecisos_65": None, "OBN_65": 4.2, "PS_65": 38.3, "AD_65": 28.8, "Chega_65": 11.4, "IL_65": 2.5, "BE_65": 3.3, "CDU_65": 6.7, "Livre_65": 3.6, "PAN_65": 1.2,
# Intenção de voto por status social
"Indecisos_D": None, "OBN_D": 4.3, "PS_D": 30.1, "AD_D": 25.7, "Chega_D": 19.5, "IL_D": 7.2, "BE_D": 2.6, "CDU_D": 2.5, "Livre_D": 4.0, "PAN_D": 4.2,
"Indecisos_C2": None, "OBN_C2": 4.0, "PS_C2": 24.8, "AD_C2": 29.3, "Chega_C2": 24.7, "IL_C2": 5.6, "BE_C2": 3.1, "CDU_C2": 4.2, "Livre_C2": 1.1, "PAN_C2": 3.2,
"Indecisos_C1": None, "OBN_C1": 3.2, "PS_C1": 32.2, "AD_C1": 26.4, "Chega_C1": 19.3, "IL_C1": 4.2, "BE_C1": 4.5, "CDU_C1": 3.9, "Livre_C1": 4.0, "PAN_C1": 2.3,
"Indecisos_AB": None, "OBN_AB": 6.0, "PS_AB": 24.7, "AD_AB": 34.8, "Chega_AB": 10.5, "IL_AB": 6.9, "BE_AB": 4.1, "CDU_AB": 2.8, "Livre_AB": 7.5, "PAN_AB": 2.8,
# Observação
"Observacao": "Sondagem realizada pela Aximage para o Diário de Notícias entre 23 e 28 de janeiro de 2025, com 800 entrevistas efetivas (679 CAWI e 121 CATI). Amostragem por quotas cruzando sexo, idade e região (NUTSII). Universo: indivíduos maiores de 18 anos residentes em Portugal. Taxa de resposta: 68.36%. Margem de erro máximo para um intervalo de confiança de 95% é de +/- 3.5%. Resultados com distribuição de indecisos, baseados em votação anterior e questões adicionais relativas à esquerda/direita. Abstenção estimada em 20.0% (sem distribuição de indecisos) e 21.4% (com distribuição). Margem de erro por segmento: Norte=8.5%, Centro=7.4%, AML=6.2%, Sul e Ilhas=9.3%, Masculino=5.0%, Feminino=4.8%, 18-34=7.1%."
}



sondagem_legislativas_Pitagorica_01032025 = {
# Informações gerais
"Entidade_de_sondagens": "Pitagorica", "Cliente": "JN, CNN, TVI, TSF e O Jogo",
"Data_de_Recolha": "23/02/2025-27/02/2025", "Data_de_publicação": "01/02/2025", "Ultimo_dia_de_recolha": "27/02/2025",
"Tamanho_da_amostra": 400, "Taxa_de_resposta": 65, "Intervalo_de_confiança": 95.5, "Margem_de_erro": 5,
# Intenção de voto geral
"Indecisos": 7.8, "OBN": 4.2, "PS": 27.2, "AD": 35.6, "Chega": 16.5, "IL": 5.5, "BE": 3.7, "CDU": 3.5, "Livre": 4.1, "PAN": 2.9,
# Observação
"Observacao": "Sondagem realizada pela Aximage para o Diário de Notícias entre 23 e 28 de janeiro de 2025, com 800 entrevistas efetivas (679 CAWI e 121 CATI). Amostragem por quotas cruzando sexo, idade e região (NUTSII). Universo: indivíduos maiores de 18 anos residentes em Portugal. Taxa de resposta: 68.36%. Margem de erro máximo para um intervalo de confiança de 95% é de +/- 3.5%. Resultados com distribuição de indecisos, baseados em votação anterior e questões adicionais relativas à esquerda/direita. Abstenção estimada em 20.0% (sem distribuição de indecisos) e 21.4% (com distribuição). Margem de erro por segmento: Norte=8.5%, Centro=7.4%, AML=6.2%, Sul e Ilhas=9.3%, Masculino=5.0%, Feminino=4.8%, 18-34=7.1%."
}


data = [sondagem_legislativas_pitagorica_07012025,
        sondagem_legislativas_Aximage_24012025,
        sondagem_legislativas_Intercampus_27012025,
        sondagem_legislativas_ICS_ISCTE_29012025,
        sondagem_legislativas_pitagorica_31012025,
        sondagem_legislativas_Aximage_01022025
        ]

# %%
# Criar o DataFrame diretamente a partir dos dados
df = pd.DataFrame(data, columns=features)

# Guardar o DataFrame no CSV
df.to_csv("../data/sondagens_portugal.csv", index=False, encoding='utf-8')

# %%
#df.drop_duplicates()
print(df)
# Out:
#   Entidade_de_sondagens                             Cliente  \
# 0            Pitagórica  TVI, CNN Portugal, JN, TSF, O Jogo
# 1               Aximage               Jornal Folha Nacional
# 2           Intercampus           CM, CMTV, Jornal Negócios
# 3             ICS/ISCTE                       Grupo Impresa
# 4            Pitagórica  TVI, CNN Portugal, JN, TSF, O Jogo
# 5               Aximage                  Diário de Notícias
#
#          Data_de_Recolha Data_de_publicação Ultimo_dia_de_recolha  \
# 0  28/12/2024-05/01/2025         07/01/2025            05/01/2025
# 1  16/01/2025-21/01/2025         24/01/2025            21/01/2025
# 2  21/01/2025-26/01/2025         27/01/2025            27/01/2025
# 3  09/01/2025-26/01/2025         20/01/2025            26/01/2025
# 4  21/01/2025-26/01/2025          31/01/202            26/01/2025
# 5  23/01/2025-28/01/2025         01/02/2025            28/01/2025
#
#    Tamanho_da_amostra  Taxa_de_resposta  Num_M  Num_F  Taxa_M  ...  AD_D  \
# ...
